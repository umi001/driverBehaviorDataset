# %%
import pandas as pd

# %%
df1=pd.read_csv('16_acelerometro_terra_labelled.csv')
df2=pd.read_csv('17_acelerometro_terra_labelled.csv')
df3=pd.read_csv('20_acelerometro_terra_labelled.csv')
df4=pd.read_csv('21_acelerometro_terra_labelled.csv')

# %%
df2
# Out:
#       Mean_x0   Mean_x1   Mean_x2   Mean_x3   Mean_x4   Mean_x5   Mean_x6  \
# 0    0.002670  0.020178 -0.034762 -0.030369  0.000762  0.032326  0.044174
# 1    0.047786  0.025228  0.029380 -0.014125 -0.014738  0.008600  0.034535
# 2   -0.000950  0.023418  0.016502  0.021798 -0.011490 -0.012440  0.007235
# 3   -0.058628 -0.029789 -0.003931 -0.002281  0.005713 -0.019347 -0.019038
# 4   -0.081045 -0.069837 -0.046875 -0.023209 -0.018034 -0.008747 -0.028161
# 5   -0.058254 -0.069650 -0.065976 -0.049719 -0.030218 -0.024737 -0.015820
# 6   -0.072608 -0.065431 -0.070636 -0.067634 -0.054297 -0.037283 -0.031576
# 7    0.004419 -0.034094 -0.042148 -0.051872 -0.053223 -0.044511 -0.031326
# 8   -0.046095 -0.020838 -0.038095 -0.043134 -0.050717 -0.052035 -0.044737
# 9   -0.025383 -0.035739 -0.022353 -0.034917 -0.039584 -0.046494 -0.048228
# 10  -0.025383 -0.035739 -0.022353 -0.034917 -0.039584 -0.046494 -0.048228
# 11   0.038845  0.006731 -0.010878 -0.007053 -0.020164 -0.026513 -0.034303
# ...

# %%
frames=[df1,df2,df3,df4]

# %%
acceleration=pd.concat([df1,df2,df3,df4])

# %%
acceleration
# Out:
#       Mean_x0   Mean_x1   Mean_x2   Mean_x3   Mean_x4   Mean_x5   Mean_x6  \
# 0    0.047234 -0.011573 -0.076034 -0.080470 -0.045436 -0.014244 -0.009917
# 1    0.085305  0.066269  0.020719 -0.035699 -0.047315 -0.023646 -0.000023
# 2    0.021936  0.053621  0.051492  0.021024 -0.024172 -0.035773 -0.017134
# 3    0.012566 -0.037036 -0.018886  0.000977  0.008103  0.014850  0.002011
# 4    0.031955  0.022261 -0.014039 -0.006176  0.007173  0.012078  0.017294
# 5    0.068730  0.050343  0.037751  0.006653  0.008805  0.017432  0.020171
# 6   -0.035640  0.016545  0.021682  0.019403 -0.001805  0.001398  0.009851
# 7   -0.075969 -0.055804 -0.014293 -0.002731  0.000329 -0.014166 -0.009654
# 8   -0.013879 -0.044924 -0.041829 -0.014189 -0.004960 -0.002039 -0.014125
# 9   -0.030778 -0.022329 -0.040209 -0.039067 -0.017507 -0.009263 -0.006145
# 10  -0.000541 -0.015660 -0.015066 -0.030292 -0.031361 -0.014679 -0.008017
# 11   0.047658  0.023559  0.005446  0.000615 -0.014702 -0.018191 -0.005774
# ...
